# %%
import pandas as pd

#mega = pd.read_csv('mega.csv',sep=' ')
#mega.head()

megasena = pd.read_excel('megasena.xlsx',na_filter=False,usecols=range(1,21))

r, _ = megasena.shape

rIdxPares = []

for x in range(1,r,2):
    rIdxPares.append(x)
#print(rIdxPares)

megasena = pd.read_excel('megasena.xlsx', na_filter=False, usecols=range(1,21), skiprows=rIdxPares)
megasena.to_csv('megatransform.csv')
rIdxPares
#print(megasena.columns)
megasena = pd.read_excel('megasena.xlsx', na_filter=False, usecols=range(1,21),skiprows=rIdxPares)
megasena.head()
megasena[megasena['Local'].str.contains(', RN', regex=False)]
# Out:
#                   Local Data do Sorteio Coluna 1 Coluna 2 Coluna 3 Coluna 4  \
# 114           CAICÓ, RN      2000-07-29        8       40       41       44
# 145  Pau dos Ferros, RN      2001-09-01       13       23       24       34
# 285            ASSU, RN      2004-06-16        3        9       16       20
# 432           NATAL, RN      2007-05-12        5       27       36       40
# 433      Santa Cruz, RN      2007-05-19       21       22       25       40
# 548   CURRAIS NOVOS, RN      2009-07-25        9       10       21       36
# 659         MOSSORÓ, RN      2011-06-11       18       40       47       54
# 784           CAICÓ, RN      2013-07-24       16       17       23       42
#
#     Coluna 5 Coluna 6 Ganhadores Faixa 1 Ganhadores Faixa 2  \
# 114       53       56                  0                 94
# 145       45       53                  0                116
# 285       33       60                  0                162
# ...
